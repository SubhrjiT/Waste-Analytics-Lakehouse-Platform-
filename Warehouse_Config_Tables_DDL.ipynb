# %%
# %%sql
# CREATE TABLE [fwh_datamart].[CONFIGURATION].[TRUX_SILVER_OBJECT_CONFIGURATION]
# (
# ID	INT,
# OBJECT_NAME	VARCHAR(100),
# IS_RUN	BIT,
# CHECKPOINT_COLUMN_NAME	VARCHAR(100),
# KEY_COLUMN_NAME	VARCHAR(100),
# FREQUENCY_IN_MINUTES	INT,
# SOURCE_NAME	VARCHAR(100),
# OPERATION_TYPE	VARCHAR(20),
# IS_PROCESSED	BIT,
# BRONZE_LAKEHOUSE_NAME	VARCHAR(200),
# BRONZE_TABLE_NAME	VARCHAR(200),
# SILVER_LAKEHOUSE_NAME	VARCHAR(200),
# SILVER_TABLE_NAME	VARCHAR(200),
# NOTEBOOK_NAME	VARCHAR(200),
# MODIFIED_ON	DATETIME2(0),
# MODIFIED_BY	VARCHAR(100)
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_datamart].[CONFIGURATION].[SALESFORCE_SILVER_OBJECT_CONFIGURATION]
# (
# ID	INT,
# OBJECT_NAME	VARCHAR(100),
# IS_RUN	BIT,
# CHECKPOINT_COLUMN_NAME	VARCHAR(100),
# KEY_COLUMN_NAME	VARCHAR(100),
# FREQUENCY_IN_MINUTES	INT,
# SOURCE_NAME	VARCHAR(100),
# OPERATION_TYPE	VARCHAR(20),
# IS_PROCESSED	BIT,
# BRONZE_LAKEHOUSE_NAME	VARCHAR(200),
# BRONZE_TABLE_NAME	VARCHAR(200),
# SILVER_LAKEHOUSE_NAME	VARCHAR(200),
# SILVER_TABLE_NAME	VARCHAR(200),
# NOTEBOOK_NAME	VARCHAR(200),
# MODIFIED_ON	DATETIME2(0),
# MODIFIED_BY	VARCHAR(100)
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_datamart].[CONFIGURATION].[SALESFORCE_BRONZE_OBJECT_CONFIGURATION]
# (
#   ID	INT,
# OBJECT_NAME	VARCHAR(100),
# IS_RUN	BIT,
# COLUMN_NAME	VARCHAR(MAX),
# KEY_COLUMN_NAME	VARCHAR(100),
# FREQUENCY_IN_MINUTES	INT,
# SOURCE_NAME	VARCHAR(100),
# SOURCE_SCHEMA	VARCHAR(100),
# SOURCE_TABLE_NAME	VARCHAR(100),
# SELECT_QUERY	VARCHAR(MAX),
# OPERATION_TYPE	VARCHAR(50),
# INCREMENTAL_IDENTIFIER	VARCHAR(50),
# INCREMENTAL_IDENTIFIER_TYPE	VARCHAR(50),
# COMPUTED_QUERY	VARCHAR(MAX),
# IS_PROCESSED	BIT,
# BRONZE_LAKEHOUSE_NAME	VARCHAR(200),
# BRONZE_TABLE_NAME	VARCHAR(200),
# SILVER_LAKEHOUSE_NAME	VARCHAR(200),
# SILVER_TABLE_NAME	VARCHAR(200),
# NOTEBOOK_NAME	VARCHAR(200),
# COMPUTED_SELECT_QUERY	VARCHAR(MAX),
# [CHECKPOINT]	DATETIME2(0),
# IS_EXTRACT_FROM_SOURCE	BIT,
# LEVEL_SEQUENCE	INT,
# IS_DELETED_RECORDS	BIT,
# MODIFIED_ON	DATETIME2(0),
# MODIFIED_BY	VARCHAR(100)
#
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_datamart].[CONFIGURATION].[FIELD_MAPPING]
# (
#    ID	[int],
# OBJECT_NAME	[varchar](255),
# DESTINATION_TABLE	[varchar](255),
# DESTINATION_COLUMN_NAMES	[varchar](max),
# DESTINATION_COLUMN_DATA_TYPE	[varchar](max),
# SOURCE_NAME	[varchar](255),
# SOURCE_TABLE	[varchar](255),
# SOURCE_COLUMN_NAMES	[varchar](max),
# ADDED_ON	[datetime2](3),
# ADDED_BY	[varchar](255),
# MODIFIED_ON	[datetime2](3),
# MODIFIED_BY	[varchar](255)
#
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_gold].[CONFIGURATION].[FIELD_MAPPING]
# (
# 	[ID] [int] NULL,
# 	[OBJECT_NAME] [varchar](255) NULL,
# 	[DESTINATION_TABLE] [varchar](255) NULL,
# 	[DESTINATION_COLUMN_NAMES] [varchar](max) NULL,
# 	[DESTINATION_COLUMN_DATA_TYPE] [varchar](max) NULL,
# 	[SOURCE_NAME] [varchar](255) NULL,
# 	[SOURCE_TABLE] [varchar](255) NULL,
# 	[SOURCE_COLUMN_NAMES] [varchar](max) NULL,
# 	[ADDED_ON] [datetime2](3) NULL,
# 	[ADDED_BY] [varchar](255) NULL,
# 	[MODIFIED_ON] [datetime2](3) NULL,
# 	[MODIFIED_BY] [varchar](255) NULL
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_gold].[CONFIGURATION].[PIPELINE_RUN_LOGS]
# (
# 	[PIPELINE_NAME] [varchar](100) NULL,
# 	[PIPELINE_TRIGGER_NAME] [varchar](100) NULL,
# 	[SOURCE_DATABASE_NAME] [varchar](100) NULL,
# 	[PIPELINE_RUN_ID] [varchar](100) NULL,
# 	[PIPELINE_START_TIME] [varchar](100) NULL,
# 	[PIPELINE_END_TIME] [varchar](100) NULL,
# 	[STATUS] [bit] NULL
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_gold].[CONFIGURATION].[PROCESSED_AUDIT_LOGS]
# (
# 	[ID] [int] NULL,
# 	[OBJECT_NAME] [varchar](100) NULL,
# 	[SOURCE] [varchar](100) NULL,
# 	[DESTINATION] [varchar](100) NULL,
# 	[TARGET_LAYER] [varchar](100) NULL,
# 	[TOTAL_RECORDS_COUNT] [int] NULL,
# 	[UPDATE_RECORDS_COUNT] [int] NULL,
# 	[INSERT_RECORDS_COUNT] [int] NULL,
# 	[PIPELINE_NAME] [varchar](100) NULL,
# 	[PIPELINE_RUNID] [varchar](100) NULL,
# 	[RUN_START_TIME] [datetime2](3) NULL,
# 	[RUN_END_TIME] [datetime2](3) NULL,
# 	[TRIGGER_NAME] [varchar](100) NULL,
# 	[TRIGGER_TYPE] [varchar](100) NULL,
# 	[TRIGGER_TIME] [datetime2](3) NULL,
# 	[DATA_EXTRACTION_QUERY] [varchar](max) NULL,
# 	[SOURCE_DATABASE_NAME] [varchar](100) NULL,
# 	[MODIFIED_ON] [datetime2](3) NULL,
# 	[MODIFIED_BY] [varchar](100) NULL
# )
# GO

# %%
# %%sql
# CREATE TABLE [fwh_gold].[CONFIGURATION].[PROCESSED_ERROR_LOGS]
# (
# 	[ID] [int] NULL,
# 	[PIPELINE_NAME] [varchar](200) NULL,
# 	[PIPELINE_RUNID] [varchar](200) NULL,
# 	[SOURCE] [varchar](200) NULL,
# 	[DESTINATION] [varchar](200) NULL,
# 	[TRIGGER_TYPE] [varchar](200) NULL,
# 	[TRIGGER_ID] [varchar](200) NULL,
# 	[TRIGGER_NAME] [varchar](200) NULL,
# 	[TRIGGER_TIME] [datetime2](3) NULL,
# 	[NO_PARELLEL_COPIES] [int] NULL,
# 	[COPY_DURATION_IN_SECS] [varchar](200) NULL,
# 	[EFFECTIVE_INTEGRATION_RUNTIME] [varchar](200) NULL,
# 	[SOURCE_TYPE] [varchar](200) NULL,
# 	[SINK_TYPE] [varchar](200) NULL,
# 	[EXECUTION_STATUS] [varchar](200) NULL,
# 	[ERROR_DESCRIPTION] [varchar](max) NULL,
# 	[ERROR_CODE] [varchar](200) NULL,
# 	[ERROR_LOGGED_TIME] [varchar](200) NULL,
# 	[FAILURE_TYPE] [varchar](200) NULL,
# 	[ADDED_ON] [datetime2](3) NULL,
# 	[ADDED_BY] [varchar](200) NULL
# )
# GO
